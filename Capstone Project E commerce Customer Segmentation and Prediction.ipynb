# %% [markdown]
# # <p style="background-color:#0b5394; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Capstone Project | E-commerce Customer Segmentation and Prediction</p>
#
#
# Presented by : Tanvi Vishwanath Surve.
#
# Email : tanvivishwanath95@gmail.com
#
# Campus : Shivajinagar Campus, Pune

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #f44336 ; font-size:120%; text-align:left">
# Note: If Any issue getting in color scheme of the Project., PLease try to change jupiter Theme from Settings

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #0b5394 ; font-size:120%; text-align:left">
#
# <h3 align="left"><font color=#ffffff>Problem:</font></h3>
#
# This project aims to enhance marketing strategies and customer retention for an e-commerce company by gaining a deeper understanding of their customer base based on their purchasing patter. By leveraging machine learning, the project seeks to segment customers and predict future purchasing behavior. The goal is to develop a robust customer segmentation model and a predictive classifier to categorize customers based on their purchasing patterns, enabling the company to tailor marketing strategies, improve customer retention, and optimize inventory management.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #0b5394 ; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=#ffffff>Objectives:</font></h3>
#
# * _Research Methodology: Conduct thorough exploratory data analysis to understand customer behavior and purchasing patterns. Implement and compare the performance of multiple segmentation algorithms.
# * _
# Model Selection: Evaluate various clustering methods such as K-means, hierarchical clustering, and DBSCAN to identify the most effective customer segments
# * _Feature Engineering: Analyze the importance of different customer attributes, such as purchase frequency, recency, and monetary value, in driving segmentation.
# * _Report Structure: Document the entire process, including code, results, and key decisions taken. Prepare a final presentation showcasing findings and recommendations
# * _Report Structure: Document the entire process, including code, results, and key decisions taken. Prepare a final presentation showcasing findings and recommendations.
# *  _Actionable Recommendations: Provide insights on the most important customer segments and suggest strategies for targeted marketing and customer retention..ion.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#
#         Project Outline : How I approached the problem
#
#         I Found 2 Parts to work on : 1)Customer segmentation 2)Products segmentation
#
#           1)  Feature Engineering : I Realised, with Recency, Monetary and Frequency, 'Cancellation Percentage of Each Customer also matter in Churning.' I wanted to Highlight that. So, though I have Visualised data on Recency, Monetary and Frequency I have trained the model with CancellationFreq Feature. To segment Customers More Deeply.
#
#                 I have Also considered Monetary and Frequency outliers, seperate as well as common property and trained model for Non Outliers dataset to generalise the model. But In the end I have called Outliers dataset, plotted and visualised, Then clustered them with labeling each segment with -ve sign (-1,-2,-3) because it was manual and not by model. Gave Business recommandations for each segment and added them back to Main dataset.
#
#                 So, this is how, I did not Ignored outliers since there were Upper bracket Outliers as well as Lower Bracket Outliers., and recommandated the Solutions for each segment manually
#
#          2)Model Building and Evaluation
#
#                  ] Segment Visualising For Interpretation step: Before Interpretation step, I have created a ccount plot for 'Customers Count in each cluster' on the scatterplot for Recency, Monetary, Frequency and CancellationFreq respectively, to visualise On the same output. So, the Viewer can See Visualisation and can relate to each cluster Interpretation
#
#         3)Product Popularity finding for targeted  product Promotions
#
#                 Intituively, CancellationFreq and Quality/Popularity of the product have relation.So, I ranked the columns with rank() function., used qcut() to seperate and Identify most popular products to least Popular product., And have added these ratings to final Dataset/excel file. So, viewer can relate and visualise and the same time the Customer Segment and their Purchase product, and same time find out rating of the product., to generalise and Predict the behaivior.
#
#         4)visualising final findings of the Project. : In the last we have visualised Cluster Distribution with Average Feature Values., with the help of overlapping Lineplot and Barplot.
#
#         5)Dataset Overview : while working on the iven dataset :
#
#              Original_Dataset : rows : 5,41,909
#
#                 prediction_dataset Final : rows : 4,06,789
#
#                 Overall Data Retained and Used : 75%

# %% [markdown]
# <a id="Contents_Table"></a>
# <div style="border-radius:10px; padding: 15px; background-color: #ea9999 ; font-size:115%; text-align:left">
#
# <h3 align="left"><font color=#963131>Table of Contents:</font></h3>
#
# * [Data Preprocessing](#PreProcessingDataset)
# * [1 | Import Libraries](#import)
# *  [2 | Dataset overview](#Dataset_overview)
#  - [Step 2.1 | Dataset Basic Information](#basic)
#  - [Step 2.2 | Summary Statistics](#num_statistics)
#  - [Step 2.3 | Customer_Dataset : In Nutshell](#Customer_Dataset:In_Nutshell)
# * [3 |  EDA ](#EDA)
#     - [Step 2 | Preprocessing By Column ](#Preprocessing_By_Column)
# * [4 | Feature_Engineering](#Feature_Creation)
#      - [Step 4:1| Feature_Engineering and finalising dataset for clustering](#Feature)
#           - [Step 4:1:1 | Recency, Frequency, Monetary ](#RFM)
#     - [Step 4:2| Outliers_Treatment](#Outliers)
#     -  [Histogram plotting](#Histogram_plotting)
#     -  [Boxplot creation](#Boxplot_plotting)
#           - [Scatterplot creation](#Scatterplot_plotting)
#           - [OutliersTreatment](#Outliers)
#           - [4:2:1 |plotting the plots with not_outliers dataset](#not_outliers_dataset)
#           - [Histogram plotting ](#Histogram)
#           - [Boxplot](#Boxplot)
#           - [3d scatterplot](#3d_scatterplot)
#           - [4:3 |Features scaling](#Features_scaling)
#          - [Standardization](#Standardization)
#          - [3d scatterplot](#3d_scatterplot)
# * [Model Building And Evaluation](#Machine_Learning)
#   - [5 | Model building for Segment clusters creation](#KMEANSclusters_creation)
#   - [5:1 | K-Means](#K-Means_Model)
#     - [5:1:1 | Elbow Method &  Silhouette score](#Elbow_Method_Silhouette)
#       - [5:2 | Hierachical clustering](#Hierachical_clustering)
#       - [5:2:1 | Dendogram](#Dendogram)
#           - [5:3 | dbscan ](#dbscan)
#               - [5:3:1 | Plotting DBCluster](#plotDendogram)
# * - [6 |Model_Training](#Model_Building)
#     - [6:1 | Visualising_Segmentation K=4 with diff color themes](#Visualising_Segmentation)
#       -  [6:1:1 | 3d scatterplot](#3dscatterplot_k4)
#       - [6:1:2 | Final Segmentation_Visualisation ](#Segmentation_Visualisation)
# * [Interpretation And Business Recommandation](#Interpretation)
# * [8 | Saved Kmeans trained model](#savetrained_model)
# * [9 | Product_Promotion](#Product_Promotion)
#    - [9:1 |StockCode Exploration and Clean Dataset](#StockCode)
#       - [9:2 | Product Segmentation Cell](#ProductSegmentationCell)
#       - [9:3 | Product Popularity Ratings in Nutshel](#Product_Popularity)
#       - [9:4 | Treating Previously Segmented Outliers_datasets](#TreatingOutliers)
#          - [9:4:1 | Visualising Outliers and Segmentation](#TreatedOutliers)
#       - [9:5 | Interpretation And Business Recommandation for Outliers](#OutliersInterpretation)
# * [10 | Saving_Data_Excel](#Saving_Data_Excel)
#   - [10:1 | Adding_Cluster_Labels](#Adding_Cluster_Labels)
#   - [10:2 | Finalised Dataset From Last Checked Copy](#PicknChoose)
# * [11 | Saved New Prediction Dataset for future referance](#savetrained_model)
# * [12 | Final Visualisation Of Customer Segmentation and Prediction Project](#savetrained_model1)

# %% [markdown]
# <a id="PreProcessingDataset"></a>
# # <p style="background-color:#0b5394; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Data Preprocessing</p>

# %% [markdown]
# <a id="import"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394; font-size:115%; text-align:left">
#
# 1 | Import Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date, time
import datetime as dt
from pandas import Series

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans, AgglomerativeClustering 
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA

from sklearn import metrics
from sklearn.cluster import DBSCAN
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import cross_val_score 
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold
from sklearn.metrics import silhouette_score, davies_bouldin_score

import scipy.cluster.hierarchy as shc

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# First of all, let's load the dataset:

# %%
customer_data = pd.read_csv("data.csv", encoding='latin-1') 

# dataset had some latin variables.. to be able to load, we had to encode latin

# %%
customer_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  12-01-2010 08:26       2.55     17850.0  United Kingdom
# 1  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 2  12-01-2010 08:26       2.75     17850.0  United Kingdom
# 3  12-01-2010 08:26       3.39     17850.0  United Kingdom
# 4  12-01-2010 08:26       3.39     17850.0  United Kingdom

# %% [markdown]
# <a id="Dataset_overview"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394; font-size:115%; text-align:left">
#
# 2 | Dataset Overview
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="Dataset_overview"></a>
# # <b><span style='color:#ff826e'> </span><span style='color:red'> 2 | Dataset Overview</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="basic"></a>
# # <b><span style='color:#ff826e'>Step 2.1 |</span><span style='color:red'> Dataset Basic Information</span></b>

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# there is clear sign that ., NaN, null, missing values in  CustomerID

# %% [markdown]
# <a id="num_statistics"></a>
# # <b><span style='color:#ff826e'>Step 2.2 |</span><span style='color:red'> Summary Statistics</span></b>

# %%
customer_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
customer_data.describe(include='O') #specifically for object/string like data., so include 'O' capital O
# Out:
#        InvoiceNo StockCode                         Description  \
# count     541909    541909                              540455
# unique     25900      4070                                4223
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq        1114      2313                                2369
#
#              InvoiceDate         Country
# count             541909          541909
# unique             23260              38
# top     10/31/2011 14:41  United Kingdom
# freq                1114          495478

# %%
customer_data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# The very imp consideration Target column is Customer ID column, which has null values.., lets drop those rows so we get a clear dataset to work upon.
# there is clear sign that ., NaN, null, missing values in
# NaNs pose a threat to the seamless flow of data analysis and computations.
#
# NaNs can disrupt data analysis and computations.
# Algorithm Compatibility
# NaNs can affect data visualization.
# They can lead to errors in machine learning model training.

# %%
customer_data1 = customer_data.dropna()
# null value dropped : 135080 customers,  Description : 1454

# %%
len(customer_data1[customer_data1['Quantity'] == 0])
# Out:
# 0

# %%
len(customer_data1[customer_data1['UnitPrice'] == 0])         # UnitPrice cannot be zero., we can drop these rows.
# Out:
# 40

# %%
#customer_data2 = customer_data2.dropna('Total_Price', == 0)
customer_data1 = (customer_data1[(customer_data1.UnitPrice != 0)])
customer_data1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# <a id="Customer_Dataset:In_Nutshell"></a>
# # <b><span style='color:#ff826e'>Step 2.3 |</span><span style='color:red'>Customer_Dataset : In Nutshell</span></b>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# #customer_data1['InvoiceNo'].value_counts()
#
# #customer_data1['CustomerID'].value_counts()
#
# #customer_data1['StockCode'].value_counts()
#
# #customer_data1['Country'].value_counts()
#
# we have 4372 customers., these 4372 customers placed 22190 number of total orders between time period from 2010-01-12 to 2011-12-10 (approax 2years).
# most valuable customer finding by calculating each customer buying freq to total number of orders.
#
# Unique Invoices : 22190
#
#
# customers : 4372
#
#
# stock codes : 3,684
#
#
# countries : 37
#
#
# Time_Period : 1 Year 10 Months 29 Days              # (2010-01-12 to 2011-12-10)

# %% [markdown]
# <a id="Customer_Dataset:In_Nutshell"></a>
# # <b><span style='color:#ff826e'>3 |</span><span style='color:red'> EDA</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="Preprocessing_By_Column"></a>
# # <b><span style='color:#ff826e'>Step 2.3 |</span><span style='color:red'>Preprocessing By Column</span></b>

# %%
customer_data1['InvoiceNo'].str.replace('[0-9]', '' , regex=True).unique()                  
# value_counts() # to find out are there unique consistant values or not.
# Out:
# array(['', 'C'], dtype=object)

# %%
customer_data1['InvoiceNo'].str.replace('[0-9]', '' , regex=True).value_counts()
# Out:
# InvoiceNo
#      397884
# C      8905
# Name: count, dtype: int64

# %%
display(customer_data1.loc[(customer_data1.Quantity<0)])
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#  I wanted to find out the invoice starting with 'C' have any corrilation with negative quantity in quantity column., that can be translated as return orders.
# #here,
#
# C Prefix orders : 8905.
# negative Quantity rows : 8872.,
#
# that means those order are returned or canceled orders.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# total -ve quantities & total invoiveNo, have relation. we interprete these as -ve quantities showing how much quantity were cancelled

# %%
customer_data1 = customer_data1.drop(columns= ['Description'])
customer_data1.head(2)
# Out:
#   InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1    536365     71053         6  12-01-2010 08:26       3.39     17850.0
#
#           Country
# 0  United Kingdom
# 1  United Kingdom

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# Create A product DataFrame for Future Reference

# %%
product_dataset = customer_data1.copy()
product_dataset.head()
# Out:
#   InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1    536365     71053         6  12-01-2010 08:26       3.39     17850.0
# 2    536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3    536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4    536365    84029E         6  12-01-2010 08:26       3.39     17850.0
#
#           Country
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
customer_dataS = customer_data1.copy()
customer_dataS.shape
# Out:
# (406789, 7)

# %% [markdown]
# <a id="Feature_Creation"></a>
# # <b><span style='color:#ff826e'>4 |</span><span style='color:red'>Feature_Engineering</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# '''
# Here I want to create:
#
#     1)create total price spent column as New feature., for better insight
#         (@) add a column for cancelled orders., with -ve total price spent
#     2)combine all orders by a single customer on a particular date.
#
# '''

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# creating total price spent column as feature/pca., for better insight

# %%
customer_dataS['Total_Price'] = customer_dataS['Quantity'] * customer_dataS['UnitPrice']

# %%
customer_dataS = customer_dataS.drop(columns = ['Quantity','UnitPrice','Country'])

# %%
display(customer_dataS.loc[(customer_dataS.Total_Price<0)])
# Out:
#        InvoiceNo StockCode       InvoiceDate  CustomerID  Total_Price
# 141      C536379         D  12-01-2010 09:41     14527.0       -27.50
# 154      C536383    35004C  12-01-2010 09:49     15311.0        -4.65
# 235      C536391     22556  12-01-2010 10:24     17548.0       -19.80
# 236      C536391     21984  12-01-2010 10:24     17548.0        -6.96
# 237      C536391     21983  12-01-2010 10:24     17548.0        -6.96
# ...          ...       ...               ...         ...          ...
# 540449   C581490     23144  12-09-2011 09:57     14397.0        -9.13
# 541541   C581499         M  12-09-2011 10:28     15498.0      -224.69
# 541715   C581568     21258  12-09-2011 11:57     15311.0       -54.75
# 541716   C581569     84978  12-09-2011 11:58     17315.0        -1.25
# 541717   C581569     20979  12-09-2011 11:58     17315.0        -6.25
#
# [8905 rows x 5 columns]

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#     (@) add a column for cancelled orders., with -ve total price spent
#      cancelled orders feature column

# %%
customer_dataS['Cancelled_Order'] = customer_dataS['Total_Price'].map(lambda x: x < 0)
display(customer_dataS.loc[(customer_dataS.Total_Price<0)])
# Out:
#        InvoiceNo StockCode       InvoiceDate  CustomerID  Total_Price  \
# 141      C536379         D  12-01-2010 09:41     14527.0       -27.50
# 154      C536383    35004C  12-01-2010 09:49     15311.0        -4.65
# 235      C536391     22556  12-01-2010 10:24     17548.0       -19.80
# 236      C536391     21984  12-01-2010 10:24     17548.0        -6.96
# 237      C536391     21983  12-01-2010 10:24     17548.0        -6.96
# ...          ...       ...               ...         ...          ...
# 540449   C581490     23144  12-09-2011 09:57     14397.0        -9.13
# 541541   C581499         M  12-09-2011 10:28     15498.0      -224.69
# 541715   C581568     21258  12-09-2011 11:57     15311.0       -54.75
# 541716   C581569     84978  12-09-2011 11:58     17315.0        -1.25
# 541717   C581569     20979  12-09-2011 11:58     17315.0        -6.25
#
#         Cancelled_Order
# 141                True
# 154                True
# 235                True
# 236                True
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#     Encode 'cancelled order' column., to replace false 0 and true = -1
#
#     so that In below standardisation cell., It will represent the idea why I have included the cancelled order column
#
#     I want to extract only date of order from Invoice date., since for customer segmentation timing is not important

# %%
customer_dataS['Cancelled_Order'] = customer_dataS['Cancelled_Order'].replace('False'== 0 , 'True'== -1)

display(customer_dataS.loc[(customer_dataS.Total_Price==0)])         #we donot have 0 total price in the dataset.
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, InvoiceDate, CustomerID, Total_Price, Cancelled_Order]
# Index: []

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# need to change datatype of InvoiceDate column, as it is showing object and it is expected to be 'datetime'.
#
# So lets change dtype of InvoiceDate column.

# %%
customer_dataS['InvoiceDate'] = pd.to_datetime(customer_dataS['InvoiceDate'], 
                            format ='mixed',dayfirst = 'bool')
customer_dataS['InvoiceDate'] = pd.to_datetime(customer_dataS['InvoiceDate'],format="%m.%d.%Y %I:%M:%S.%f %p" )
customer_dataS['InvoiceDate']
# Out:
# 0        2010-01-12 08:26:00
# 1        2010-01-12 08:26:00
# 2        2010-01-12 08:26:00
# 3        2010-01-12 08:26:00
# 4        2010-01-12 08:26:00
#                  ...
# 541904   2011-09-12 12:50:00
# 541905   2011-09-12 12:50:00
# 541906   2011-09-12 12:50:00
# 541907   2011-09-12 12:50:00
# 541908   2011-09-12 12:50:00
# Name: InvoiceDate, Length: 406789, dtype: datetime64[ns]

# %%
df = pd.DataFrame(customer_dataS['InvoiceDate'])             #: pd.date_range('2016-1-1 10:00:00.123', periods=10, freq='5H')})
customer_dataS['Date_Invoice'] = df['InvoiceDate'].dt.date
customer_dataS['Time_Invoice'] = df['InvoiceDate'].dt.time
             #Added Date_Invoice  Time_Invoice columns, seperated from InvoiceDate	
customer_dataS.head(2)
# Out:
#   InvoiceNo StockCode         InvoiceDate  CustomerID  Total_Price  \
# 0    536365    85123A 2010-01-12 08:26:00     17850.0        15.30
# 1    536365     71053 2010-01-12 08:26:00     17850.0        20.34
#
#    Cancelled_Order Date_Invoice Time_Invoice
# 0            False   2010-01-12     08:26:00
# 1            False   2010-01-12     08:26:00

# %%
customer_dataS = customer_dataS.drop(columns=['InvoiceDate','Time_Invoice'])
customer_dataS.head(2)
# Out:
#   InvoiceNo StockCode  CustomerID  Total_Price  Cancelled_Order Date_Invoice
# 0    536365    85123A     17850.0        15.30            False   2010-01-12
# 1    536365     71053     17850.0        20.34            False   2010-01-12

# %% [markdown]
# <a id="Feature"></a>
# # <b><span style='color:#ff826e'>4:1 |</span><span style='color:red'>Feature_Engineering and finalising dataset for clustering</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
dt.timedelta(1)
# Out:
# datetime.timedelta(days=1)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# dt.timedelta(1) function is generally used for calculating differences in dates and
#
# also can be used for date manipulations in Python. It is one of the easiest ways to perform date manipulations

# %%
pin_date = max(customer_dataS['Date_Invoice']) + dt.timedelta(1)
pin_date
# Out:
# datetime.date(2011, 12, 11)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # calculate columns to groupby per customerID so that we can relate their purchasing patterns
#
# ''' To create a cleaned ready to cluster dataset for model building for customer segmentation,
#
# we want a purspective out of Original Dataset as : (total revenue per customerID): (freq of orders/InvoiceNo): (freq of cancellation of orders): (freq of successful orders)
#
#         Columns I want : customerID(As_index) ,
#
#             freq of orders/InvoiceNo,
#
#             freq of successful orders,
#
#             freq of cancellation of orders,
#
#             total revenue per customerID
#
# '''

# %% [markdown]
# <a id="RFM"></a>
# # <b><span style='color:#ff826e'>4:1:1</span><span style='color:red'>Recency, Frequency, Monetary </span></b>

# %%
clustering_data = customer_dataS.groupby('CustomerID').agg({
    'Date_Invoice': lambda x: (pin_date - x.max()).days,
    'InvoiceNo': 'count',
    'Total_Price': 'sum',
    'Cancelled_Order' : 'sum'
})
clustering_data.head()
# Out:
#             Date_Invoice  InvoiceNo  Total_Price  Cancelled_Order
# CustomerID
# 12346.0              327          2         0.00                1
# 12347.0               41        182      4310.00                0
# 12348.0               77         31      1797.24                0
# 12349.0               20         73      1757.55                0
# 12350.0              312         17       334.40                0

# %%
clustering_data.rename(columns= {
    'Date_Invoice': 'DaysFreq',
    'InvoiceNo': 'PurchaseFreq',
    'Total_Price': 'TotalAmount',
    'Cancelled_Order': 'CancellationsFreq'
}, inplace=True)
clustering_data.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq
# CustomerID
# 12346.0          327             2         0.00                  1
# 12347.0           41           182      4310.00                  0
# 12348.0           77            31      1797.24                  0
# 12349.0           20            73      1757.55                  0
# 12350.0          312            17       334.40                  0

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#         display(clustering_data.loc[(clustering_data.TotalAmount==0)])
#
#         clustering_data = (clustering_data[(clustering_data.TotalAmount!= 0)])
#
#         Created a new dataset by deleting all rows with Total Amount representing 0

# %%
clustering_data = (clustering_data[(clustering_data.TotalAmount!= 0)])
clustering_data.shape
# Out:
# (4364, 4)

# %%
clustering_data ['CancellationsFreq'] = clustering_data ['CancellationsFreq']/clustering_data ['PurchaseFreq'] * 100 
clustering_data .head() #in percentage as how much percentage of purchase was returned.
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq
# CustomerID
# 12347.0           41           182      4310.00           0.000000
# 12348.0           77            31      1797.24           0.000000
# 12349.0           20            73      1757.55           0.000000
# 12350.0          312            17       334.40           0.000000
# 12352.0           74            95      1545.41          10.526316

# %% [markdown]
# <a id="Outliers"></a>
# # <b><span style='color:#ff826e'>4:2 </span><span style='color:red'>Outliers_Treatment </span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# Histogram plotting

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.hist(clustering_data['DaysFreq'])         #, camp='rainbow'
plt.xlabel('DaysFreq')
plt.ylabel('Count')
plt.title('By_Recency')


plt.subplot(1,4,2)
plt.hist(clustering_data['PurchaseFreq'])         #, camp='rainbow'
plt.xlabel('PurchaseFreq')
plt.ylabel('Count')
plt.title('By_Frequency')

plt.subplot(1,4,3)
plt.hist(clustering_data['TotalAmount'])         #, camp='rainbow'
plt.xlabel('TotalAmount')
plt.ylabel('Count')
plt.title('By_Monetory')


plt.subplot(1,4,4)
plt.hist(clustering_data['CancellationsFreq'])         #, camp='rainbow'
plt.xlabel('CancellationsFreq')
plt.ylabel('Count')
plt.title('By_CancellationsFreq')

# Adjust subplot spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
# Boxplot creation

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.boxplot(clustering_data['DaysFreq'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('DaysFreq')
plt.title('By_Recency')


plt.subplot(1,4,2)
plt.boxplot(clustering_data['PurchaseFreq'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('PurchaseFreq')
plt.title('By_Frequency')

plt.subplot(1,4,3)
plt.boxplot(clustering_data['TotalAmount'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('TotalAmount')
plt.title('By_Monetory')


plt.subplot(1,4,4)
plt.boxplot(clustering_data['CancellationsFreq'], patch_artist=True)         #, camp='rainbow'
plt.xlabel('CancellationsFreq')
plt.title('By_CancellationsFreq')

# Adjust subplot spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# Scatterplot creation

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(projection='3d')

scatter = ax.scatter(clustering_data['TotalAmount'],clustering_data['PurchaseFreq'],clustering_data['DaysFreq'])

ax.set_xlabel('Monetory')
ax.set_ylabel('Frequency')
ax.set_zlabel('Recancy')

ax.set_title('3d scatterplot clustering_data')

plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# clearly there are outliers, which might affect model performance, but we cannot delete/drop them altogether., since the ouliers in monetory, frequencychart are some of the valuable customers as well. lets seperate outliers from common data, and then look at then seperately.

# %% [markdown]
# # <b><span style='color:#ff826e'> </span><span style='color:#0b5394'> lets split data into quarters </span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# first part: 1.5 is commonly accepted to find outliers.,here it is finding data greater than interquantile_range
#
#
# second part : here it is finding data less than interquantile_range

# %%
m_q1 = clustering_data['TotalAmount'].quantile(0.25)   #25th percentile of total transformed_data set
m_q3 = clustering_data['TotalAmount'].quantile(0.75)    #3rd quartile,75th percentile of total transformed_data set

interquantile_range = m_q3 - m_q1

monetory_outliers = clustering_data[(clustering_data['TotalAmount']> (m_q3 + 1.5*interquantile_range)) | (clustering_data['TotalAmount']< (m_q1 - 1.5*interquantile_range))].copy()
# first part: 1.5 is commonly accepted to find outliers.,here it is finding data greater than interquantile_range
# second part : here it is finding data less than interquantile_range

monetory_outliers.describe()
# Out:
#          DaysFreq  PurchaseFreq    TotalAmount  CancellationsFreq
# count  423.000000    423.000000     423.000000         423.000000
# mean    27.732861    383.600473   11638.593144           3.500923
# std     37.356005    640.560391   24254.291245           7.369163
# min      1.000000      1.000000   -4287.630000           0.000000
# 25%      7.000000    154.500000    4321.590000           0.472493
# 50%     16.000000    260.000000    5739.460000           1.639344
# 75%     27.000000    408.000000    9199.510000           4.016211
# max    306.000000   7983.000000  279489.020000         100.000000

# %%
f_q1 = clustering_data['PurchaseFreq'].quantile(0.25)   #25th percentile of total transformed_data set
f_q3 = clustering_data['PurchaseFreq'].quantile(0.75)    #3rd quartile,75th percentile of total transformed_data set

interquantile_range = f_q3 - f_q1

frequency_outliers = clustering_data[(clustering_data['PurchaseFreq']> (f_q3 + 1.5*interquantile_range)) | (clustering_data['PurchaseFreq']< (f_q1 - 1.5*interquantile_range))].copy()

frequency_outliers.describe()
# Out:
#          DaysFreq  PurchaseFreq    TotalAmount  CancellationsFreq
# count  380.000000    380.000000     380.000000         380.000000
# mean    25.192105    493.442105   10058.544921           2.324030
# std     30.455338    646.662721   25499.087945           3.861076
# min      1.000000    230.000000     576.300000           0.000000
# 25%      7.000000    277.750000    2608.942500           0.181516
# 50%     16.000000    344.000000    4561.905000           1.003197
# 75%     28.000000    474.000000    7318.080000           2.729730
# max    236.000000   7983.000000  279489.020000          32.517483

# %%
monetory_outliers.shape
# Out:
# (423, 4)

# %%
frequency_outliers.shape
# Out:
# (380, 4)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#         these two outliers datsets we extracted from transformed data, might have overlapping.
#
#         It makes an intuitive sence that customers that are frequently buying., might be also contributing monetory outliers data.
#
#         But this is just guess, we will explore it more, but now lets see out normal range data.

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# here we are extracting index seperate from which are not in our outliers datasets that we just formed.and created new dataframe

# %%
not_outliers = clustering_data[(~clustering_data.index.isin(monetory_outliers.index)) & (~clustering_data.index.isin(frequency_outliers.index))]
not_outliers.describe()
# Out:
#           DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq
# count  3799.000000   3799.000000  3799.000000        3799.000000
# mean    112.734141     51.238484   806.528835           3.154138
# std     117.530048     48.739293   772.200804          10.969555
# min       1.000000      1.000000 -1592.490000           0.000000
# 25%      26.000000     15.000000   255.650000           0.000000
# 50%      70.000000     33.000000   537.060000           0.000000
# 75%     172.000000     73.000000  1106.465000           1.639344
# max     698.000000    229.000000  3580.130000         100.000000

# %%
not_outliers.shape
# Out:
# (3799, 4)

# %% [markdown]
# <a id="not_outliers_dataset"></a>
# # <b><span style='color:#0b5394'>4:2:1 |</span><span style='color:#0b5394'>plotting the plots with not_outliers dataset</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # Histogram plotting

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.hist(not_outliers['DaysFreq'])         #, camp='rainbow'
plt.xlabel('DaysFreq')
plt.ylabel('Count')
plt.title('By_Recency')


plt.subplot(1,4,2)
plt.hist(not_outliers['PurchaseFreq'])         #, camp='rainbow'
plt.xlabel('PurchaseFreq')
plt.ylabel('Count')
plt.title('By_Frequency')

plt.subplot(1,4,3)
plt.hist(not_outliers['TotalAmount'])         #, camp='rainbow'
plt.xlabel('TotalAmount')
plt.ylabel('Count')
plt.title('By_Monetory')


plt.subplot(1,4,4)
plt.hist(not_outliers['CancellationsFreq'])         #, camp='rainbow'
plt.xlabel('CancellationsFreq')
plt.ylabel('Count')
plt.title('By_CancellationsFreq')

# Adjust subplot spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # Boxplot plotting

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,4,1)
plt.boxplot(not_outliers['DaysFreq'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('DaysFreq')
plt.title('By_Recency')


plt.subplot(1,4,2)
plt.boxplot(not_outliers['PurchaseFreq'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('PurchaseFreq')
plt.title('By_Frequency')

plt.subplot(1,4,3)
plt.boxplot(not_outliers['TotalAmount'],  patch_artist=True)         #, camp='rainbow'
plt.xlabel('TotalAmount')
plt.title('By_Monetory')


plt.subplot(1,4,4)
plt.boxplot(not_outliers['CancellationsFreq'], patch_artist=True)         #, camp='rainbow'
plt.xlabel('CancellationsFreq')
plt.title('By_CancellationsFreq')

# Adjust subplot spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 3d scatterplot

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(projection='3d')

scatter = ax.scatter(not_outliers['TotalAmount'], not_outliers['PurchaseFreq'], not_outliers['DaysFreq'])

ax.set_xlabel('Monetory')
ax.set_ylabel('Frequency')
ax.set_zlabel('Recancy')

ax.set_title('3d scatterplot of Not_outliers')

plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#         This new dataset do have outliers but we can tolerate that compared to the original transformed dataset outliers.

# %% [markdown]
# <a id="Features_scaling"></a>
# # <b><span style='color:#0b5394'>4:3 |</span><span style='color:#0b5394'>Features scaling </span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # Standardization
#
# This method of scaling is basically based on the central tendencies and variance of the data. This helps us achieve a normal distribution(if it is already normal but skewed) of the data with a mean equal to zero and a standard deviation equal to 1

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(not_outliers)

data_scaled
# Out:
# array([[-0.30408262, -0.41529425,  1.2831398 , -0.28757349],
#        [-0.78912882,  0.44654691,  1.23173448, -0.28757349],
#        [ 1.69566927, -0.70257464, -0.6114873 , -0.28757349],
#        ...,
#        [-0.91677256, -0.90777491, -0.93991662, -0.28757349],
#        [-0.15941971, -0.78465475, -0.81586519,  0.41376033],
#        [-0.95081089,  0.38498683,  1.33499842, -0.28757349]])

# %%
scaled_dataframe = pd.DataFrame(data_scaled, index=not_outliers.index ,columns=('DaysFreq','PurchaseFreq','TotalAmount','CancellationsFreq'))

scaled_dataframe.shape
# Out:
# (3799, 4)

# %%
scaled_dataframe
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq
# CustomerID
# 12348.0    -0.304083     -0.415294     1.283140          -0.287573
# 12349.0    -0.789129      0.446547     1.231734          -0.287573
# 12350.0     1.695669     -0.702575    -0.611487          -0.287573
# 12352.0    -0.329611      0.897988     0.956977           0.672146
# 12353.0     0.793654     -0.969335    -0.929322          -0.287573
# ...              ...           ...          ...                ...
# 18278.0    -0.321102     -0.866735    -0.819362          -0.287573
# 18280.0     0.410722     -0.846215    -0.810685          -0.287573
# 18281.0    -0.916773     -0.907775    -0.939917          -0.287573
# 18282.0    -0.159420     -0.784655    -0.815865           0.413760
# 18287.0    -0.950811      0.384987     1.334998          -0.287573
#
# [3799 rows x 4 columns]

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # 3d scatterplot for scaled dataframe

# %%
fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(projection='3d')

scatter = ax.scatter(scaled_dataframe['TotalAmount'], scaled_dataframe['PurchaseFreq'], scaled_dataframe['DaysFreq'])

ax.set_xlabel('Monetory')
ax.set_ylabel('Frequency')
ax.set_zlabel('Recancy')

ax.set_title('3d scatterplot of scaled_dataframe')

plt.show()

# %%
scaled_dataframe
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq
# CustomerID
# 12348.0    -0.304083     -0.415294     1.283140          -0.287573
# 12349.0    -0.789129      0.446547     1.231734          -0.287573
# 12350.0     1.695669     -0.702575    -0.611487          -0.287573
# 12352.0    -0.329611      0.897988     0.956977           0.672146
# 12353.0     0.793654     -0.969335    -0.929322          -0.287573
# ...              ...           ...          ...                ...
# 18278.0    -0.321102     -0.866735    -0.819362          -0.287573
# 18280.0     0.410722     -0.846215    -0.810685          -0.287573
# 18281.0    -0.916773     -0.907775    -0.939917          -0.287573
# 18282.0    -0.159420     -0.784655    -0.815865           0.413760
# 18287.0    -0.950811      0.384987     1.334998          -0.287573
#
# [3799 rows x 4 columns]

# %% [markdown]
# <a id="Machine_Learning"></a>
# # <p style="background-color:#0b5394; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Model Building And Evaluation</p>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="KMEANSclusters_creation"></a>
# # <b><span style='color:#ff826e'>5 |</span><span style='color:red'>Model building for Segment clusters creation</span></b>

# %% [markdown]
# <a id="K-Means_Model"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # 5:1 | K-Means

# %%
inertia_values = []
silhouette_scores = []
K_range = range(2, 11)  # You can adjust the range as needed

for K in K_range:
    kmeans = KMeans(n_clusters=K, max_iter=300, random_state=42)         #max_iter=300
    kmeans.fit(scaled_dataframe)
    
    # Inertia (within-cluster sum of squares)
    inertia_values.append(kmeans.inertia_)
    
    # Silhouette Score
    silhouette = silhouette_score(scaled_dataframe, kmeans.labels_)
    silhouette_scores.append(silhouette)

# %%
print('silhouette_scores : ', silhouette_scores)
# Out:
# silhouette_scores :  [0.3963392765211063, 0.4267630204271382, 0.3783471554099384, 0.33809662874322866, 0.35028203301299776, 0.3548297639143872, 0.36520183222086383, 0.3301899144083674, 0.30003089661164656]

# %% [markdown]
# <a id="Elbow_Method_Silhouette"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 5:1:1 | Elbow Method &  Silhouette score
#
# To Evaluate Number of K values/ Clusters by considering
#
# Inertia (Within-cluster Sum of Squares)
#
# Silhouette Score

# %%
plt.figure(figsize=(13, 6))

plt.subplot(1, 2, 1)
plt.plot(K_range, inertia_values, marker='o', linestyle='-')      #marker='o',
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia (Within-cluster Sum of Squares)')
plt.title('Elbow Method')
#plt.show()


plt.subplot(1, 2, 2)
plt.plot(K_range, silhouette_scores, marker='o', linestyle='-')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#     # Interpretation : cluster options., we have 4 a better number of cluster options

# %% [markdown]
# <a id="Hierachical clustering"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 5:2 | Hierachical clustering
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# ''' clustering on Transformed dataset with customerID as index.,with approx 3800 rows.
#
# and not the original dataset 4lakh rows of data., We can use hierarchical clustering. '''

# %%
pca = PCA(n_components=2)      #how any column we want to create

# %%
df_pca = pca.fit_transform(scaled_dataframe)

# %%
data_pca_df = pd.DataFrame(df_pca) 
data_pca_df.columns = ['P1','P2']

# %% [markdown]
# <a id="Dendogram"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 5:2:1 | Dendogram

# %%
plt.figure(figsize=(15,6), layout='tight')
plt.title('Dendogram with data_pca_df')

dendogram = shc.dendrogram((shc.linkage(data_pca_df, method='ward')))

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#         Interpretation : hierarchical clustering is showing 4 optimal clusters.

# %% [markdown]
# <a id="dbscan "></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 5:3 | dbscan
#
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
scaler = StandardScaler()
DB_scaled = scaler.fit_transform(not_outliers)

# %%
# Initialize DBSCAN model
# eps: The maximum distance between two samples for them to be considered as in the same neighborhood.
# min_samples: The number of samples in a neighborhood for a point to be considered as a core point.
dbscan = DBSCAN(eps=0.3, min_samples=10)
dbscan
# Out:
# DBSCAN(eps=0.3, min_samples=10)

# %%
# Fit the model
labels = dbscan.fit_predict(DB_scaled)
labels
# Out:
# array([-1,  0,  0, ...,  0,  0,  0], dtype=int64)

# %%
unique_labels = set(labels)
unique_labels
# Out:
# {-1, 0, 1, 2, 3, 4, 5}

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#     -1 indicates., those points are the noise and dont fit anywhere in cluster., other than -ve cluster all points are fit in some clusters.

# %% [markdown]
# <a id="plotDendogram"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 5:3:1 | Plotting DBCluster
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
# Plotting the clusters
plt.figure(figsize=(8, 6))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise
        col = 'k'
        marker = 'x'
        label = 'Noise'
    else:
        marker = 'o'
        label = f'Cluster {k+1}'
        
    class_member_mask = (labels == k)
    xy = DB_scaled[class_member_mask]
    plt.scatter(xy[:, 0], xy[:, 1], c=col, marker=marker, s=50, label=label)

# Adding plot details
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#  Looking at Elbow and silhouette_scores,Dendogram, DBSCAN it seems that 4,4, 4 and 6., respectively.
#
#  Majority stands with  k = 4 clusters nice in depth segmentation.,
#
#  #  Lets Build Model with K=4 Clusters

# %% [markdown]
# <a id="Model_Building"></a>
# # <b><span style='color:#ff826e'>6 |</span><span style='color:red'>Model_Training</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
# Perform K-means clustering
# Assuming X is your dataset
kmeans = KMeans(n_clusters=4, max_iter=1000, random_state=42)
kmeans.fit(scaled_dataframe)

# Get cluster labels
labels = kmeans.labels_

# Inertia (Within-cluster sum of squares)
inertia = kmeans.inertia_

# Silhouette Score
sil_score = silhouette_score(scaled_dataframe , labels)

print(f"Inertia (Within-cluster sum of squares): {inertia}")
print(f"Silhouette Score: {sil_score}")
# Out:
# Inertia (Within-cluster sum of squares): 5265.644023955066
# Silhouette Score: 0.3783471554099384

# %%
scaled_dataframe['cluster4'] = kmeans.fit_predict(scaled_dataframe)
not_outliers['cluster4'] = kmeans.fit_predict(scaled_dataframe)

# %%
not_outliers['cluster4'].value_counts()
# Out:
# cluster4
# 1    2011
# 2     926
# 3     810
# 0      52
# Name: count, dtype: int64

# %%
not_outliers.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq  cluster4
# CustomerID
# 12348.0           77            31      1797.24           0.000000         1
# 12349.0           20            73      1757.55           0.000000         3
# 12350.0          312            17       334.40           0.000000         2
# 12352.0           74            95      1545.41          10.526316         3
# 12353.0          206             4        89.00           0.000000         2

# %% [markdown]
# <a id="Visualising_Segmentation"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 6:1 | Visualising_Segmentation K=4 with diff color themes

# %% [markdown]
# <a id="3dscatterplot_k4"></a>
#
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 6:1:1 | 3d scatterplot
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
cluster_colors = {0:'#1f77b4',  #blue
                  1:'#ff7f0e',   #orange
                  2:'#2ca02c',   #green
                  3:'#d62728'}   #red

colors = scaled_dataframe['cluster4'].map(cluster_colors)

fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(projection='3d')


scatter = ax.scatter(not_outliers['TotalAmount'], 
                     not_outliers['PurchaseFreq'], 
                     not_outliers['DaysFreq'], 
                     c=colors)

ax.set_xlabel('Monetory')
ax.set_ylabel('Frequency')
ax.set_zlabel('Recancy')

ax.set_title('3d scatterplot of customer data by 4 clusters')

plt.show()

# %% [markdown]
# <a id="Segmentation_Visualisation"></a>
#
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# # 6:1:2 | Final Segmentation_Visualisation
#
# ScatterPlot + Histogram Plot For Visualising and Comparing Trained Segmentations
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,4,1)
plt.scatter(not_outliers['cluster4'], not_outliers['DaysFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Recency')
plt.title('By_Recency')
plt.subplot(1,4,1)
sns.histplot(data=not_outliers, x='cluster4' )

plt.subplot(1,4,2)
plt.scatter(not_outliers['cluster4'], not_outliers['PurchaseFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Frequency')
plt.title('By_Frequency')
plt.subplot(1,4,2)
sns.histplot(data=not_outliers, x='cluster4' )

plt.subplot(1,4,3)
plt.scatter(not_outliers['cluster4'], not_outliers['TotalAmount'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Monetary')
plt.title('By_Monetary')
plt.subplot(1,4,3)
sns.histplot(data=not_outliers, x='cluster4' )

plt.subplot(1,4,4)
plt.scatter(not_outliers['cluster4'], not_outliers['CancellationsFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('CancellationsFreq')
plt.title('By_Cancellations_Freq')


plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="Interpretation"></a>
# # <p style="background-color:#0b5394; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">Interpretation And Business Recommandation </p>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # 7 | Interpretation
#
#
# This Plotting represents., Customer_Count in each cluster Number And overlapping with each feature presentation in each cluster
#
#     Cluster 0 : 'Churn', "Re-Engage",
#         1) Highest presentation in (Cancellation feature + negative Moneytary Feature) And
#             this is very Much Interpreting that these customers represented by Cluster 3, are prone to or most likely to churn.
#         2)And a good sign is, these customers are very less in number compared to total Number of Customers, as shown by Histogram.
#
#     (Cluster  1 , 2, 3: These three clusters Represent Almost Similar numbers of Customers with Cancellation Freq, so, lets interprete them based on Recency, Frequency, Monetory Features.)
#     Cluster 1 & 2 :
#         1)Both Cluster Show similar contribution In Frequency and Moneytory Feature .
#         2)Cluster 1 : "Nurture"
#             (a) Represents Highest numbers of Customers
#             (b) But in terms of Recency contribution., This cluster segment has lowest Contribution even after having maority customers.
#             (c) In interpretation, I will say, this segment has already very good representation in Monetory feature.,
#             (d) If considered and addressed proper way, this Cluster will transform into Most valuable customer Segment for Future Revenue parspective.
#
#         3)Cluster 2 : "Retain"
#             (a) We Specifically want to focus on Cluster 1 significant representation in Monetory feature.
#                 Even after representing moderate numbers of customers, this segment has the highest monetory contribution and less cancellation frequency.
#             (b) Second Imp reason is.,
#                     It has slightly more representation in Recency as well Frequency in orders than Cluster 0.
#                     Very less representation than most valuable segment Cluster 1,
#                     still this segment manages to give highest in Revenue purspective.
#             (c)This segment must be specifically considered the most in the 'Revenue centric Decision Making Process'.
#                     correcting faults in supply chain,competetive (prices+deliveryspeed+Quality) Ensurance,
#                     ease in handling website traffic, visual appealings, offers, discounts, exchange offers, etc
#     Cluster 3 : "Reward"
#         1) Cluster 3 showing highest contribution in the monetory Sence for the Company.
#         2) Considering Recency, Frequency, Monetory these customers are showing Trust in the long run on the Respected E-commerce platform.
#         3) Cluster 3 Can be Interpretated as Most Valuable Customer Segment.
#
# --------------------------------------------
#
#     Summary of Cluster Names:
#
#         Cluster 0 : "Re-Engage",
#
#         Cluster 1 : "Nurture",
#
#         Cluster 2 : "Retain",
#
#         Cluster 3 : "Reward".
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#         for Customer Segmentation we will run the similar cell at the end to avoid any issues because of string lables.
#                 cluster_labels = {
#                             0: "RETAIN",
#                             1: "RE-ENGAGE",
#                             2: "NURTURE",
#                             3: "REWARD"
#                 }
#
#             not_outliers['cluster4'] = not_outliers['cluster4'].map(cluster_labels)
#
#             not_outliers.head()

# %% [markdown]
# <a id="savetrained model"></a>
# # <b><span style='color:#ff826e'>8 |</span><span style='color:red'>Saved Kmeans trained model</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
import pickle

# %%
pickle.dump(kmeans,open( 'kmeansCustSegPrediction.pkl','wb'))

# %%
kmeans = pickle.load(open('kmeansCustSegPrediction.pkl','rb'))

# %% [markdown]
# <a id="Product_Promotion"></a>
# # <b><span style='color:#ff826e'>9 |</span><span style='color:red'>Product_Promotion</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="StockCode"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# 9:1 |StockCode Exploration and Clean Dataset

# %%
product_dataset.head(2)        # we reated a copy of cleaned dataset for future referance., that copy we are using here
# Out:
#   InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0    536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1    536365     71053         6  12-01-2010 08:26       3.39     17850.0
#
#           Country
# 0  United Kingdom
# 1  United Kingdom

# %%
product_dataset['StockCode'].value_counts() # there are products ordered multiple time.
# Out:
# StockCode
# 85123A    2077
# 22423     1904
# 85099B    1662
# 84879     1418
# 47566     1415
#           ...
# 85224        1
# 35650        1
# 90060B       1
# 84569C       1
# 84795C       1
# Name: count, Length: 3684, dtype: int64

# %% [raw]
# Here is stock code or product code, they are combination of discrete and continues codes
# There are some suffixes or might even be prefixes in code. Lets exprore this column.

# %%
product_dataset['StockCode'] = product_dataset['StockCode'].astype('str')
product_dataset[product_dataset['StockCode'].str.match("^\\d{5}$") == False]        #typing regex pattern for 5 digit numbers., to return everything else other than 5 digit codes
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 2         536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3         536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4         536365    84029E         6  12-01-2010 08:26       3.39     17850.0
# 45        536370      POST         3  12-01-2010 08:45      18.00     12583.0
# ...          ...       ...       ...               ...        ...         ...
# 541778    581578    84997C         8  12-09-2011 12:16       4.15     12713.0
# 541809    581579    85099C        10  12-09-2011 12:19       1.79     17581.0
# 541838    581580    84993A         2  12-09-2011 12:20       0.42     12748.0
# 541844    581580    85049A         1  12-09-2011 12:20       1.25     12748.0
# 541853    581580    85049E         2  12-09-2011 12:20       1.25     12748.0
#
#                Country
# ...

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# We are added a Cell, where return will be codes that donot matches the 'False' filter, 5 digit with repeating letters in stockcode column

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# these look like leget transactions, but we donot have anything specified in data documentation for stockcode, other than its a product code.
# so, we are going to consider them. and explore the preprocessing for model building.
#
# Let us find If there are any other stock codes other than the filter we applied above., that is 5 digit and with string suffix
#
# So, there are codes that donot matches the 'False' filter, and are not numbers as well\
#
# lets couunt how many are such codes in the stockcode column.

# %%
product_dataset['StockCode'] = product_dataset['StockCode'].astype('str')
product_dataset[(product_dataset['StockCode'].str.match("^\\d{5}$") == False) 
& (product_dataset['StockCode'].str.match("^\\d{5}[a-zA-Z]+$") == False)]['StockCode'].unique()
# Out:
# array(['POST', 'D', 'C2', 'M', 'BANK CHARGES', 'PADS', 'DOT', 'CRUK'],
#       dtype=object)

# %% [raw]
# so these are distinct codes that donot follow our pattern. lets find out how many of them , we want to actually consider before proceeding

# %%
product_dataset[product_dataset['StockCode'].str.contains('^[POST, D, C2, M, BANK CHARGES, PADS, DOT, CRUK]')]
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 5         536365     22752         2  12-01-2010 08:26       7.65     17850.0
# 6         536365     21730         6  12-01-2010 08:26       4.25     17850.0
# 7         536366     22633         6  12-01-2010 08:28       1.85     17850.0
# 8         536366     22632         6  12-01-2010 08:28       1.85     17850.0
# 10        536367     22745         6  12-01-2010 08:34       2.10     13047.0
# ...          ...       ...       ...               ...        ...         ...
# 541904    581587     22613        12  12-09-2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12-09-2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12-09-2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12-09-2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12-09-2011 12:50       4.95     12680.0
#
#                Country
# ...

# %% [raw]
# 'Stockcode' : 'Count' = {'POST' : 1196 , 'D' : 93, 'C2' : 134, 'M' : 459, 'BANK CHARGES' = 12, 'PADS' : 3, 'DOT' : 16, 'CRUK' : 16 }

# %%
product_dataset[product_dataset['StockCode'].str.contains('^POST')] #POSTAGE ,Discount ,CARRIAGE,Manual ,Bank Charges ,PADS TO MATCH ALL CUSHIONS ,DOTCOM POSTAGE,CRUK Commission
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 45        536370      POST         3  12-01-2010 08:45       18.0     12583.0
# 386       536403      POST         1  12-01-2010 11:27       15.0     12791.0
# 1123      536527      POST         1  12-01-2010 13:04       18.0     12662.0
# 5073      536840      POST         1  12-02-2010 18:27       18.0     12738.0
# 5258      536852      POST         1  12-03-2010 09:51       18.0     12686.0
# ...          ...       ...       ...               ...        ...         ...
# 541198    581493      POST         1  12-09-2011 10:10       15.0     12423.0
# 541216    581494      POST         2  12-09-2011 10:13       18.0     12518.0
# 541730    581570      POST         1  12-09-2011 11:59       18.0     12662.0
# 541767    581574      POST         2  12-09-2011 12:09       18.0     12526.0
# 541768    581578      POST         3  12-09-2011 12:16       18.0     12713.0
#
#             Country
# ...

# %%
df = pd.DataFrame()
 
# append columns to an empty DataFrame
df['Stockcode'] = ['POST', 'D', 'C2', 'M', 'BANK CHARGES', 'PADS', 'DOT', 'CRUK']
df['Count'] = [1196 ,77,134,459,12,3,16,16]
df['Description'] = ['POSTAGE','Discount','CARRIAGE','Manual' ,'Bank Charges','PADS TO MATCH ALL CUSHIONS' ,'DOTCOM POSTAGE','CRUK Commission']
df['Action'] = ['Exclude From Clustering','Exclude From Clustering','Exclude From Clustering','Exclude From Clustering','Exclude From Clustering','Include in Clustering','Exclude From Clustering','Exclude From Clustering']
df
# Out:
#       Stockcode  Count                 Description                   Action
# 0          POST   1196                     POSTAGE  Exclude From Clustering
# 1             D     77                    Discount  Exclude From Clustering
# 2            C2    134                    CARRIAGE  Exclude From Clustering
# 3             M    459                      Manual  Exclude From Clustering
# 4  BANK CHARGES     12                Bank Charges  Exclude From Clustering
# 5          PADS      3  PADS TO MATCH ALL CUSHIONS    Include in Clustering
# 6           DOT     16              DOTCOM POSTAGE  Exclude From Clustering
# 7          CRUK     16             CRUK Commission  Exclude From Clustering

# %%
product_dataset1 = product_dataset.copy()

# %%
product_dataset1['StockCode'] = product_dataset1['StockCode'].astype('str')

Mask = (
    (product_dataset1['StockCode'].str.match("^\\d{5}$") == True) 
    | (product_dataset1['StockCode'].str.match("^\\d{5}[a-zA-Z]+$") == True)
    | (product_dataset1['StockCode'].str.match("^PADS") == True)
)
product_dataset1 = product_dataset1[Mask]

product_dataset1
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1         536365     71053         6  12-01-2010 08:26       3.39     17850.0
# 2         536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3         536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4         536365    84029E         6  12-01-2010 08:26       3.39     17850.0
# ...          ...       ...       ...               ...        ...         ...
# 541904    581587     22613        12  12-09-2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12-09-2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12-09-2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12-09-2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12-09-2011 12:50       4.95     12680.0
#
#                Country
# ...

# %%
product_dataset1['Total_Price'] = product_dataset1['Quantity']*product_dataset1['UnitPrice']
product_dataset1.sort_index()
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1         536365     71053         6  12-01-2010 08:26       3.39     17850.0
# 2         536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3         536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4         536365    84029E         6  12-01-2010 08:26       3.39     17850.0
# ...          ...       ...       ...               ...        ...         ...
# 541904    581587     22613        12  12-09-2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12-09-2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12-09-2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12-09-2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12-09-2011 12:50       4.95     12680.0
#
# ...

# %%
product_dataset1['Total_Price'] = product_dataset1['Quantity']*product_dataset1['UnitPrice']
product_dataset1.sort_index()
# Out:
#        InvoiceNo StockCode  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0         536365    85123A         6  12-01-2010 08:26       2.55     17850.0
# 1         536365     71053         6  12-01-2010 08:26       3.39     17850.0
# 2         536365    84406B         8  12-01-2010 08:26       2.75     17850.0
# 3         536365    84029G         6  12-01-2010 08:26       3.39     17850.0
# 4         536365    84029E         6  12-01-2010 08:26       3.39     17850.0
# ...          ...       ...       ...               ...        ...         ...
# 541904    581587     22613        12  12-09-2011 12:50       0.85     12680.0
# 541905    581587     22899         6  12-09-2011 12:50       2.10     12680.0
# 541906    581587     23254         4  12-09-2011 12:50       4.15     12680.0
# 541907    581587     23255         4  12-09-2011 12:50       4.15     12680.0
# 541908    581587     22138         3  12-09-2011 12:50       4.95     12680.0
#
# ...

# %% [markdown]
# <a id="ProductSegmentationCell"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# 9:2 | Product Segmentation Cell
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [raw]
# # Creating selected columns for product ranting and recommandation Task

# %%
transformed_data = product_dataset1.groupby('StockCode').agg({
    #'Date_Invoice': lambda x: (pin_date - x.max()).days,
    'CustomerID' : 'count',
    'InvoiceNo': 'count',
    'Quantity' : 'sum',
    'Total_Price': 'sum'
})
transformed_data.head()
# Out:
#            CustomerID  InvoiceNo  Quantity  Total_Price
# StockCode
# 10002              49         49       823       699.55
# 10080              21         21       291       114.41
# 10120              30         30       193        40.53
# 10123C              3          3         5         3.25
# 10124A              5          5        16         6.72

# %%
transformed_data .rename(columns= {
        'InvoiceNo': 'Popularity',
        'Quantity' : 'Sold_Units',
        'Total_Price': 'Monetary'
}, inplace=True)
transformed_data = transformed_data.sort_values('Popularity', ascending=False)
transformed_data.head()
# Out:
#            CustomerID  Popularity  Sold_Units   Monetary
# StockCode
# 85123A           2077        2077       34204   93979.20
# 22423            1904        1904       11545  132870.40
# 85099B           1662        1662       45066   83236.76
# 84879            1418        1418       35314   56499.22
# 47566            1415        1415       15023   67687.53

# %%
transformed_data['R_Popularity'] = transformed_data['Popularity'].rank(method='dense', na_option='top', pct=True)
transformed_data['R_Sold_Units'] = transformed_data['Sold_Units'].rank(method='dense', na_option='top', pct=True)
transformed_data['R_Monetary'] = transformed_data['Monetary'].rank(method='dense', na_option='top', pct=True)

# %%
#display(transformed_data.loc[(transformed_data.Popularity>1000)]
Cleaned_df = transformed_data.drop(columns=['Popularity','Sold_Units','Monetary'])
#Cleaned_df.head()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# 3d scatterplot transformed_data

# %%
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(projection='3d')

scatter = ax.scatter(Cleaned_df['R_Popularity'],Cleaned_df['R_Monetary'], Cleaned_df['R_Sold_Units'])

ax.set_xlabel('Popularity')
ax.set_ylabel('Monetary')
ax.set_zlabel('Sold_Units')

ax.set_title('3d scatterplot transformed_data')

plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#     Sold Units, Monetory Return ans Popularity have direct correlation as per the scatter plot. so, we can conclude,
#
#         1) the more unit of products have sold :
#
#             the more popular the product is, and as a result,
#
#             If that product is pushed by promotions,
#
#             it can bring More revenue for the company.

# %%
Popularity = range(1, 5) #[4, 3, 2, 1]
R_Popularity = pd.qcut(Cleaned_df['R_Popularity'], q=4, labels=Popularity)
Monetary	 = range(1, 5) # [1, 2, 3, 4]
R_Monetary	 = pd.qcut(Cleaned_df['R_Monetary'], q=4, labels=Monetary)
Sold_Units = range(1,5)
R_Sold_Units= pd.qcut(Cleaned_df['R_Sold_Units'], q=4, labels=Sold_Units)

Cleaned_df['Popularity'] = R_Popularity.values
Cleaned_df['Monetary'] = R_Monetary.values
Cleaned_df['Sold_Units'] = R_Sold_Units.values
Cleaned_df.head()
# Out:
#            CustomerID  R_Popularity  R_Sold_Units  R_Monetary Popularity  \
# StockCode
# 85123A           2077      1.000000      0.997723    0.999702          4
# 22423            1904      0.998134      0.970973    1.000000          4
# 85099B           1662      0.996269      0.998862    0.999403          4
# 84879            1418      0.994403      0.998293    0.998806          4
# 47566            1415      0.992537      0.986340    0.999105          4
#
#           Monetary Sold_Units
# StockCode
# 85123A           4          4
# 22423            4          4
# 85099B           4          4
# 84879            4          4
# 47566            4          4

# %% [markdown]
# <a id="Product_Popularity"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# 9:3 | Product Popularity Ratings in Nutshel : [(rating) (Count)]
#
#         product_Recommandation['Popularity'].value_counts() #= Popularity =
#
#                 [1 = 926 ], [2 =  920], [3 = 916], [4 = 915]
#
#         product_Recommandation['Monetary'].value_counts() #= Monetary =
#
#                 [1 =  920], [2 = 915],[3 = 916],[4 = 920]
#
#         product_Recommandation['Sold_Units'].value_counts() #= sale =
#
#                 [1 =  920], [2 = 916],[3 = 915],[4 = 920]
#
#
# Since the rating is almost same for all, we can drop other directly related columns monetary and sold units., and only work with Product Popularity Rating
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
product_Recommandation = Cleaned_df.drop(columns=['Monetary','Sold_Units'])
product_Recommandation['Popularity'].value_counts()
# Out:
# Popularity
# 1    926
# 2    920
# 3    916
# 4    915
# Name: count, dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#         so,
#
#            the products chosen for Targeted Marketing Campaign must be Most Popular Products That are rated 4 to 5
#
#            the products chosen for Recommandations must be rated 3 as 'You May Also Like'

# %%
Most_Popular_prod = product_Recommandation[product_Recommandation['Popularity']>2]
Most_Popular_prod['Popularity'].value_counts()
# Out:
# Popularity
# 3    916
# 4    915
# 1      0
# 2      0
# Name: count, dtype: int64

# %%
You_May_Also_Like = product_Recommandation[product_Recommandation['Popularity']==2]
You_May_Also_Like['Popularity'].value_counts()
# Out:
# Popularity
# 2    920
# 1      0
# 3      0
# 4      0
# Name: count, dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#             Connecting and merging All Segmented Datasets
#
#                 create csv file with new feature and prediction columns

# %%
product_dataset1 = product_dataset1.set_index('StockCode')

# %%
final  = product_dataset1[(product_dataset1.index.isin(product_Recommandation.index))] 
final['Promotion_product'] = product_Recommandation['Popularity']

final = final.reset_index()
final.head()
# Out:
#   StockCode InvoiceNo  Quantity       InvoiceDate  UnitPrice  CustomerID  \
# 0    85123A    536365         6  12-01-2010 08:26       2.55     17850.0
# 1     71053    536365         6  12-01-2010 08:26       3.39     17850.0
# 2    84406B    536365         8  12-01-2010 08:26       2.75     17850.0
# 3    84029G    536365         6  12-01-2010 08:26       3.39     17850.0
# 4    84029E    536365         6  12-01-2010 08:26       3.39     17850.0
#
#           Country  Total_Price Promotion_product
# 0  United Kingdom        15.30                 4
# 1  United Kingdom        20.34                 4
# 2  United Kingdom        22.00                 4
# 3  United Kingdom        20.34                 4
# 4  United Kingdom        20.34                 4

# %%
final = final.set_index('CustomerID')
final
# Out:
#            StockCode InvoiceNo  Quantity       InvoiceDate  UnitPrice  \
# CustomerID
# 17850.0       85123A    536365         6  12-01-2010 08:26       2.55
# 17850.0        71053    536365         6  12-01-2010 08:26       3.39
# 17850.0       84406B    536365         8  12-01-2010 08:26       2.75
# 17850.0       84029G    536365         6  12-01-2010 08:26       3.39
# 17850.0       84029E    536365         6  12-01-2010 08:26       3.39
# ...              ...       ...       ...               ...        ...
# 12680.0        22613    581587        12  12-09-2011 12:50       0.85
# 12680.0        22899    581587         6  12-09-2011 12:50       2.10
# 12680.0        23254    581587         4  12-09-2011 12:50       4.15
# 12680.0        23255    581587         4  12-09-2011 12:50       4.15
# 12680.0        22138    581587         3  12-09-2011 12:50       4.95
#
#                    Country  Total_Price Promotion_product
# CustomerID
# ...

# %% [markdown]
# <a id="TreatingOutliers"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # 9:4 | Treating Previously Segmented Outliers_datasets
#                 original dataset after dropping null customers became 406829 rows ,
#                 we cleaned and differentiated between Outliers and not outliers.,
#                 this dataset is No outliers data.,
#
#                 lets include the outliers dataset to identify while predicting if certain customer is A Outliers or Special.
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
overlap_data = (monetory_outliers.index.intersection(frequency_outliers.index))
# overlap_data these customers are in both moneytory as well as frequency outliers.
monetory_only_outliers = monetory_outliers.drop(overlap_data) #monetory_only_outliers.shape
frequency_only_outliers = frequency_outliers.drop(overlap_data) #frequency_only_outliers.shape
monetory_and_frq_outliers =  monetory_outliers.loc[overlap_data]

monetory_and_frq_outliers['Customer_Segment'] = -1
monetory_only_outliers['Customer_Segment'] = -2
frequency_only_outliers['Customer_Segment'] = -3

outliers_dataset = pd.concat([monetory_and_frq_outliers, monetory_only_outliers, frequency_only_outliers])
outliers_dataset.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq  \
# CustomerID
# 12359.0           10           254      6245.53           2.362205
# 12362.0           13           274      5154.58           2.919708
# 12415.0           26           776    123725.45           7.989691
# 12428.0           27           300      7877.20           2.000000
# 12431.0            3           239      6416.39           1.673640
#
#             Customer_Segment
# CustomerID
# 12359.0                   -1
# 12362.0                   -1
# 12415.0                   -1
# 12428.0                   -1
# 12431.0                   -1

# %% [markdown]
# <a id="TreatedOutliers"></a>
#
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# # 9:4:1 | Visualising Outliers and Segmentation
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
plt.figure(figsize=(15,5))


plt.subplot(1,4,1)
plt.scatter(outliers_dataset['Customer_Segment'], outliers_dataset['DaysFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Recency')
plt.title('By_Recency')
plt.subplot(1,4,1)
sns.histplot(data=outliers_dataset, x='Customer_Segment' )

plt.subplot(1,4,2)
plt.scatter(outliers_dataset['Customer_Segment'],outliers_dataset['PurchaseFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Frequency')
plt.title('By_Frequency')
plt.subplot(1,4,2)
sns.histplot(data=outliers_dataset, x='Customer_Segment' )

plt.subplot(1,4,3)
plt.scatter(outliers_dataset['Customer_Segment'], outliers_dataset['TotalAmount'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Monetary')
plt.title('By_Monetary')
plt.subplot(1,4,3)
sns.histplot(data=outliers_dataset, x='Customer_Segment' )

plt.subplot(1,4,4)
plt.scatter(outliers_dataset['Customer_Segment'], outliers_dataset['CancellationsFreq'])         #, camp='rainbow'
plt.xlabel('Number of Clusters (K)')
plt.ylabel('CancellationsFreq')
plt.title('By_Cancellations_Freq')


plt.tight_layout()
plt.show()

# %% [markdown]
# <a id="OutliersInterpretation"></a>
# # <p style="background-color:#0b5394; font-family:calibri; color:white; font-size:150%; text-align:center; border-radius:15px 50px;">9:5 | Interpretation And Business Recommandation for Outliers </p>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#
#             Cluster -1 (Monetary & Frequency Outliers) DELIGHT: Characteristics: The most valuable outliers, with extreme spending and frequent purchases. They are likely your top-tier customers who require special attention. Potential Strategy: Develop VIP programs or exclusive offers to maintain their loyalty and encourage continued engagement.
#
#             Cluster -2 (Monetary Outliers) PAMPER: Characteristics: High spenders but not necessarily frequent buyers. Their purchases are large but infrequent. Potential Strategy: Focus on maintaining their loyalty with personalized offers or luxury services that cater to their high spending capacity.
#
#             Cluster -3 (Frequency Outliers) UPSELL: Characteristics: Frequent buyers who spend less per purchase. These customers are consistently engaged but might benefit from upselling opportunities. Potential Strategy: Implement loyalty programs or bundle deals to encourage higher spending per visit, given their frequent engagement.
#
#
# # for Customer Segmentation
# cluster_labels = {
#     -1: "PAMPER",
#     -2: "UPSELL",
#     -3: "DELIGHT"
# }

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
#     we will run similar cell at the end, to avoid any issues because of string dtype.
#
#         cluster_labels = {
#     -1: "PAMPER",
#     -2: "UPSELL",
#     -3: "DELIGHT"
#     }
#
#     outliers_dataset['Customer_Segment'] = outliers_dataset['Customer_Segment'].map(cluster_labels)
#
#     outliers_dataset

# %%
final1  = clustering_data[(clustering_data.index.isin(outliers_dataset.index))] 
final1['Customer_Segment'] = outliers_dataset['Customer_Segment']
final1.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq  \
# CustomerID
# 12347.0           41           182      4310.00           0.000000
# 12357.0          183           131      6207.67           0.000000
# 12359.0           10           254      6245.53           2.362205
# 12362.0           13           274      5154.58           2.919708
# 12378.0          306           219      4008.62           0.000000
#
#             Customer_Segment
# CustomerID
# 12347.0                   -2
# 12357.0                   -2
# 12359.0                   -1
# 12362.0                   -1
# 12378.0                   -2

# %%
final2  = clustering_data[(clustering_data.index.isin(not_outliers.index))] 
final2['Customer_Segment'] = not_outliers['cluster4']
final2.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq  \
# CustomerID
# 12348.0           77            31      1797.24           0.000000
# 12349.0           20            73      1757.55           0.000000
# 12350.0          312            17       334.40           0.000000
# 12352.0           74            95      1545.41          10.526316
# 12353.0          206             4        89.00           0.000000
#
#             Customer_Segment
# CustomerID
# 12348.0                    1
# 12349.0                    3
# 12350.0                    2
# 12352.0                    3
# 12353.0                    2

# %%
df = pd.concat([final1, final2])
df.shape
# Out:
# (4364, 5)

# %%
final5 =  clustering_data[(clustering_data.index.isin(df.index))] 
final5['Customer_Segment'] = df['Customer_Segment']
final5.shape
# Out:
# (4364, 5)

# %%
final.head(1)
# Out:
#            StockCode InvoiceNo  Quantity       InvoiceDate  UnitPrice  \
# CustomerID
# 17850.0       85123A    536365         6  12-01-2010 08:26       2.55
#
#                    Country  Total_Price Promotion_product
# CustomerID
# 17850.0     United Kingdom         15.3                 4

# %%
new_dataset = final[(final.index.isin(final5.index))]

# %%
#new_dataset['Stockcode'] = final['StockCode']
new_dataset['Customer_Segment'] = final5['Customer_Segment']

new_dataset
# Out:
#            StockCode InvoiceNo  Quantity       InvoiceDate  UnitPrice  \
# CustomerID
# 17850.0       85123A    536365         6  12-01-2010 08:26       2.55
# 17850.0        71053    536365         6  12-01-2010 08:26       3.39
# 17850.0       84406B    536365         8  12-01-2010 08:26       2.75
# 17850.0       84029G    536365         6  12-01-2010 08:26       3.39
# 17850.0       84029E    536365         6  12-01-2010 08:26       3.39
# ...              ...       ...       ...               ...        ...
# 12680.0        22613    581587        12  12-09-2011 12:50       0.85
# 12680.0        22899    581587         6  12-09-2011 12:50       2.10
# 12680.0        23254    581587         4  12-09-2011 12:50       4.15
# 12680.0        23255    581587         4  12-09-2011 12:50       4.15
# 12680.0        22138    581587         3  12-09-2011 12:50       4.95
#
#                    Country  Total_Price Promotion_product  Customer_Segment
# CustomerID
# ...

# %%
new_dataset = new_dataset.reset_index()

# %%
new_dataset.columns
# Out:
# Index(['CustomerID', 'StockCode', 'InvoiceNo', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'Country', 'Total_Price', 'Promotion_product',
#        'Customer_Segment'],
#       dtype='object')

# %% [markdown]
# <a id="Saving_Data_Excel"></a>
# # <b><span style='color:#ff826e'>10 |</span><span style='color:red'>Saving_Data_Excel</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %% [markdown]
# <a id="Adding_Cluster_Labels"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
#
# 10:1 | Adding_Cluster_Labels

# %%
# we are adding lebles for each of the Customer Segment. 
cluster_labels = {
    0: "RETAIN",
    1: "RE-ENGAGE",
    2: "NURTURE",
    3: "REWARD",
    -1: "PAMPER",
    -2: "UPSELL",
    -3: "DELIGHT"
}

# %%
new_dataset["Customer_Segment"] = new_dataset["Customer_Segment"].map(cluster_labels)

new_dataset
# Out:
#         CustomerID StockCode InvoiceNo  Quantity       InvoiceDate  UnitPrice  \
# 0          17850.0    85123A    536365         6  12-01-2010 08:26       2.55
# 1          17850.0     71053    536365         6  12-01-2010 08:26       3.39
# 2          17850.0    84406B    536365         8  12-01-2010 08:26       2.75
# 3          17850.0    84029G    536365         6  12-01-2010 08:26       3.39
# 4          17850.0    84029E    536365         6  12-01-2010 08:26       3.39
# ...            ...       ...       ...       ...               ...        ...
# 404805     12680.0     22613    581587        12  12-09-2011 12:50       0.85
# 404806     12680.0     22899    581587         6  12-09-2011 12:50       2.10
# 404807     12680.0     23254    581587         4  12-09-2011 12:50       4.15
# 404808     12680.0     23255    581587         4  12-09-2011 12:50       4.15
# 404809     12680.0     22138    581587         3  12-09-2011 12:50       4.95
#
# ...

# %% [markdown]
# <a id="PicknChoose"></a>
# <div style="border-radius:10px; padding: 15px; background-color:#0b5394 ; font-size:115%; text-align:left">
#
# 10:2 | Finalised Dataset From Last Checked Copy

# %%
prediction_dataset = pd.DataFrame()
prediction_dataset['InvoiceNo']  = new_dataset['InvoiceNo']
prediction_dataset['CustomerID'] = new_dataset['CustomerID']
prediction_dataset['StockCode'] = new_dataset['StockCode']
prediction_dataset['UnitPrice'] = new_dataset['UnitPrice']
prediction_dataset['Quantity'] = new_dataset['Quantity']
prediction_dataset['Country'] = new_dataset['Country']
prediction_dataset['Customer_Segment'] = new_dataset['Customer_Segment']
prediction_dataset['Promotion_product'] = new_dataset['Promotion_product']

   # final['InvoiceNo','CustomerID','StockCode','UnitPrice','Quantity','Customer_Segment','Promotion_product'])
#predic)
#final[final['InvoiceNo','CustomerID','StockCode','UnitPrice','Quantity','Customer_Segment','Promotion_product']]
prediction_dataset
# Out:
#        InvoiceNo  CustomerID StockCode  UnitPrice  Quantity         Country  \
# 0         536365     17850.0    85123A       2.55         6  United Kingdom
# 1         536365     17850.0     71053       3.39         6  United Kingdom
# 2         536365     17850.0    84406B       2.75         8  United Kingdom
# 3         536365     17850.0    84029G       3.39         6  United Kingdom
# 4         536365     17850.0    84029E       3.39         6  United Kingdom
# ...          ...         ...       ...        ...       ...             ...
# 404805    581587     12680.0     22613       0.85        12          France
# 404806    581587     12680.0     22899       2.10         6          France
# 404807    581587     12680.0     23254       4.15         4          France
# 404808    581587     12680.0     23255       4.15         4          France
# 404809    581587     12680.0     22138       4.95         3          France
#
#        Customer_Segment Promotion_product
# ...

# %% [markdown]
# <a id="savetrained model"></a>
# # <b><span style='color:#ff826e'>11 |</span><span style='color:red'>Saved New Prediction Dataset for future referance</span></b>

# %% [raw]
# prediction_dataset.to_excel('Final_Prediction_dataset.xlsx')

# %% [markdown]
# <a id="savetrained model"></a>
# # <b><span style='color:#ff826e'>12 |</span><span style='color:red'>Final Visualisation Of Customer Segmentation and Prediction Project</span></b>
#
# ⬆️ [Table of Contents](#Contents_Table)

# %%
df["Customer_Segment"] = df["Customer_Segment"].map(cluster_labels)

df.head()
# Out:
#             DaysFreq  PurchaseFreq  TotalAmount  CancellationsFreq  \
# CustomerID
# 12347.0           41           182      4310.00           0.000000
# 12357.0          183           131      6207.67           0.000000
# 12359.0           10           254      6245.53           2.362205
# 12362.0           13           274      5154.58           2.919708
# 12378.0          306           219      4008.62           0.000000
#
#            Customer_Segment
# CustomerID
# 12347.0              UPSELL
# 12357.0              UPSELL
# 12359.0              PAMPER
# 12362.0              PAMPER
# 12378.0              UPSELL

# %%
cluster_counts = df["Customer_Segment"].value_counts()

df["MonetaryValue per 100 pounds"] = df["TotalAmount"] / 100.00
feature_means = df.groupby('Customer_Segment')[['DaysFreq', 'PurchaseFreq','MonetaryValue per 100 pounds']].mean()


fig, ax1 = plt.subplots(figsize=(10, 6))

sns.barplot(x = cluster_counts.index, y = cluster_counts.values, hue_order = cluster_counts.index, palette='viridis')
ax1.set_ylabel('Number of Customers', color='b')
ax1.set_title('Cluster Distribution with Average Feature Values')

#(BarPlotter(x, y, hue, data, order, hue_order,
###   2757                       orient, color, palette, saturation,
  # 2758                       width, errcolor, errwidth, capsize, dodge)
  # 2760 if ax is None:)ax=ax1,

ax2 = ax1.twinx()

sns.lineplot(data=feature_means, ax=ax2, palette='Set2', marker='o')
ax2.set_ylabel('Average Value', color='g')

plt.savefig("Cluster_Distribution_withAverage_FeatureValues.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #0b5394 ; font-size:120%; text-align:left">
#
# <h3 align="left"><font color=#ffffff></font></h3>
#
#         Original_Dataset : rows : 5,41,909
#
#         prediction_dataset Final : rows : 4,06,789
#
#         Data Retained : 75%

# %% [markdown]
# <h2 align="left"><font color='red'>THANK YOU!</font></h2>
